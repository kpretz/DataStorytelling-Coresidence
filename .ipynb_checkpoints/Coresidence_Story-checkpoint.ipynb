# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt
import geopandas as gpd
import geodatasets

# %%
data = pd.read_csv('A0_CORESIDENCE_NATIONAL_DATASET.csv')
codebook = pd.read_csv('CODEBOOK.csv')

name_dict = dict(zip(codebook['Code'], codebook['Description']))

data.rename(name_dict, axis=1, inplace=True)
data.rename({'Country ISO nomenclature 3 digits': 'ISO_A3'}, axis=1, inplace=True)
data.head()
# Out:
#   Country ISO nomenclature 2 digits ISO_A3      Country      Continent  \
# 0                                AF    AFG  Afghanistan           ASIA
# 1                                AO    AGO       Angola         AFRICA
# 2                                AL    ALB      Albania         EUROPE
# 3                                AL    ALB      Albania         EUROPE
# 4                                AR    ARG    Argentina  LATIN-AMERICA
#
#      Sub continent  Year  Census round  Most recent year  Five years  Decade  \
# 0    Southern Asia  2015          2010                 1        2011    2010
# 1    Middle Africa  2015          2010                 1        2011    2010
# 2  Southern Europe  2008          2010                 0        2006    2000
# 3  Southern Europe  2017          2020                 1        2016    2010
# 4    South America  1970          1970                 0        1966    1960
#
#    ... Gross National Income per capita Human development index female  \
# ...

# %% [markdown]
# ## dataset: Global coresident data
# https://zenodo.org/records/8142652

# %% [markdown]
# ### Lets see the data coverage
# data collection years cyclical - every 5 years in some areas

# %%
plt.plot(data['Year'].value_counts().sort_index(), marker='.')

# %%
# download country shapefile

world_countries = gpd.read_file('ne_110m_admin_0_countries_lakes.zip')
world_countries_trimmed = world_countries[['ISO_A3', 'geometry']]

# %% [markdown]
# ### What sort of data is available?
#
# - Year collected, coutry, continent, sub continent
# - proportion of n-person households (separate call-outs for children/seniors)
# - household size, and by age
# - breakdown of size/proportion/age of male- and female-headed households
# - non-related coresidents
# - economic factors: GDP, income per capita, schooling male/female

# %%
display(data.shape)
list(data.columns)
# Out:
# (792, 179)
# ['Country ISO nomenclature 2 digits',
#  'ISO_A3',
#  'Country',
#  'Continent',
#  'Sub continent',
#  'Year',
#  'Census round',
#  'Most recent year',
#  'Five years',
#  'Decade',
#  'Sample identification',
#  'Data source',
#  'Proportion of 1-person households',
#  'Proportion of 2-persons households',
#  'Proportion of 3-persons households',
#  'Proportion of 4-persons households',
#  'Proportion of 5-persons households',
#  'Proportion of 6-persons households',
#  'Proportion of 7-persons households',
#  'Proportion of 8-persons households',
#  'Proportion of 9-persons households',
#  'Proportion of 10-persons households',
#  'Proportion of 11+persons households',
#  'Proportion of 2-3 persons households',
#  'Proportion of 4-5 persons households',
#  'Proportion of 6+ persons households',
#  'Proportion of households with at least one person 0-4 years old',
#  'Proportion of households with at least one person 65+ years old',
#  'Average household size',
# ...

# %% [markdown]
# ### Now let's look at some data over time

# %% [markdown]
# Average household size decreasing in Latin-America, decreasing very sharply in Oceania
#
# Is the change in Oceania limited to a specific country?

# %%
g = sns.relplot(data=data, x='Census round', y='Average household size', hue='Continent', kind='line')
g.fig.set_size_inches(15, 5)

# %% [markdown]
# Looks like they started surveying Australia in 2000, drastically reducing the Sub continent average starting in 2000

# %%
g = sns.relplot(data=data.loc[data['Continent']=='OCEANIA'], x='Census round', y='Average household size', hue='Country', kind='line')
g.fig.set_size_inches(15, 5)

# %% [markdown]
# Number of children decreaing in most Sub Continents except Europe and North America, which is mostly flat

# %%
g = sns.relplot(data=data, x='Census round', y='Average number of 0-4 children in the household', hue='Continent', kind='line')
g.fig.set_size_inches(15, 5)

# %% [markdown]
# Number of people age 65+ in households in all continents increasing, suggests generally aging global population.
#
# Let's check life expectancy

# %%
# 
g = sns.relplot(data=data, x='Census round', y='Average number of persons aged 65+ in the household', hue='Continent', kind='line')
g.fig.set_size_inches(15, 5)

# %% [markdown]
# Indeed increasing life expectancy in all continents, particular increase in Africa

# %%
# 
g = sns.relplot(data=data, x='Census round', y='Life expectancy', hue='Continent', kind='line')
g.fig.set_size_inches(15, 5)

# %% [markdown]
# Proportion of households which are headed by a male are decreasing in all continents, but still above 50%

# %%
g = sns.relplot(data=data, x='Census round', y='Proportion of male-headed households', hue='Continent', kind='line')
g.fig.set_size_inches(15, 5)

# %% [markdown]
# ### By country and decade

# %% [markdown]
# #### Average household size
# Initeresting spatial trend - equitorial countries tend to have higher household size than northern and southern hemisphere countries.
# This is even true within Africa.
#
# #### Note: Uncomment fig in next two cells to see interactive map with decade slider, 2010 plots shown as example
#
# #### Note: We should generally not use 2020 data in temporal trends, many survey collection processes were derailed due to COVID-19

# %%
# merge country polygons to data
data_geo = pd.merge(world_countries[['ISO_A3', 'geometry']], data, how='right', left_on='ISO_A3', right_on='ISO_A3')
# data_geo['Average household size bins'] = data_geo['Average household size'].round(0).astype('str')
data_geo.sort_values('Year', inplace=True)

import plotly.express as px
metric = 'Average household size'
fig = px.choropleth(data_frame=data_geo, geojson=data_geo.geometry, locationmode='ISO-3',
                    locations='ISO_A3', color=metric, color_continuous_scale='Plasma', hover_name='Country', 
                    animation_frame='Census round', range_color=[2, 8], 
                   width=900, height=500)

# fig

# %%
f, ax = plt.subplots(1, 1, figsize=(14, 6))
world_countries.plot(legend=True, color='white', edgecolor='black', ax=ax)
data_geo.loc[data_geo['Census round']==2010, :].plot(column=metric, legend=True, ax=ax, vmin=2, vmax=8, cmap='plasma', edgecolor='black')
# Out:
# <Axes: >

# %% [markdown]
# #### Proportion of male-headed households
#
# Countries with higher proportion of male-headed households seem to have more people per household (same equatorial countries).
#
# Though proportion is definitely decreasing over time.

# %%
metric = 'Proportion of male-headed households'
fig = px.choropleth(data_frame=data_geo, geojson=data_geo.geometry, locationmode='ISO-3',
                    locations='ISO_A3', color=metric, color_continuous_scale='cividis', hover_name='Country', 
                    animation_frame='Census round', range_color=[data_geo[metric].min(), data_geo[metric].max()], 
                   width=900, height=500)

# fig

# %%
f, ax = plt.subplots(1, 1, figsize=(14, 6))
world_countries.plot(legend=True, color='white', edgecolor='black', ax=ax)
data_geo.loc[data_geo['Census round']==2010].plot(column=metric, legend=True, ax=ax, cmap='cividis')
# Out:
# <Axes: >

# %% [markdown]
# ### How many people are in each house by continent? How does it change over time?
#
# - Africa: Fairly flat mix of household size
# - Europe: More 2-person households at the expense of 3- and 4-person households. Less kids?
# - Latin America: Less 7+ person households - possible fewer multi-family or multi-generational housing situations?
# - North America: More 1- and 2-person households at the expense of larger households. Less kids? More single people?
# - Asia: fairly flat
# - Oceania: biggest shift due to Australia being added to survey (above)

# %%
proportion_col_names = ['Proportion of 1-person households','Proportion of 2-persons households',
 'Proportion of 3-persons households','Proportion of 4-persons households', 'Proportion of 5-persons households',
 'Proportion of 6-persons households', 'Proportion of 7-persons households', 'Proportion of 8-persons households',
 'Proportion of 9-persons households', 'Proportion of 10-persons households', 'Proportion of 11+persons households'] 
data_proportions_year = data[proportion_col_names + ['Census round', 'Continent']]
data_proportions_year = data_proportions_year.groupby(['Census round', 'Continent']).mean().reset_index()
# data_proportions_year

for cont in data_proportions_year['Continent'].unique():

    data_proportions_year_sub_cont = data_proportions_year.loc[data_proportions_year['Continent'] == cont, :]
    col = sns.color_palette("Set3", 11)
    f, ax = plt.subplots(1, 1)
    ax.stackplot(data_proportions_year_sub_cont['Census round'], data_proportions_year_sub_cont[proportion_col_names].T, colors=col)
    ax.set_title(cont)
    ax.legend(proportion_col_names, bbox_to_anchor=(1.05, 1.))
    
# plt.legend(data_proportions_year.columns)

# %% [markdown]
# ### What sorts of correlations are there?
#
# - Average household size:
#     - more children --> bigger household size: obvious
#     - more seniors (65+) --> smaller household size: interesting; suggests seniors are often living alone or with one other person. Curious how senior centers are handled in this data
#     - higher GDI --> smaller household size: obvious
#     - more years of schooling --> smaller household size: obvious
# - population positively correlated with all variables
# - male heads of house
#     - more 1-person households --> fewer male heads of house: more women living alone than men?
#     - bigger household size --> more male heads: if there is a male head, more children?
#     - number of seniors in house --> fewer male heads: women live longer, but also senior women are the heads more often?
#     - higher general income measure (GDI, mean schooling, life expectancy) --> more male heads of house

# %%
corr_cols = ['Proportion of 1-person households', 'Proportion of 5-persons households', 'Proportion of 10-persons households',
            'Average household size', 'Average number of 0-4 children in the household', 'Average number of persons aged 65+ in the household',
             'Proportion of male-headed households','Population','Fertily rate', 'Life expectancy', 'Gross Domestic income', 'Mean years of schooling']
sns.heatmap(data[corr_cols].corr(numeric_only=True), vmin=-1, vmax=1, annot=True)
# Out:
# <Axes: >
